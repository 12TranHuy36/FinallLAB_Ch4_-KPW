# %%
# 2a
import os,nltk
from nltk.probability import FreqDist

L=[]
for file in os.listdir('D:/29_31_Chuong4/Data1/Data_Preprocessing'):
    L+= open('D:/29_31_Chuong4/Data1/Data_Preprocessing/'+ file,'r', encoding ='utf-8').read().split()
print('Number of words: ',len(L))

# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in L)

## show only th all results
print(frequency_dist.most_common(len(frequency_dist)))
# Out:
# Number of words:  7356
# ...

# %%
# 2b

## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)

## Build a word cloud
from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)
#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
